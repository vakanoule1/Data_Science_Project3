# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load in your data from "data/csv/br_final.csv" 
br_final = pd.read_csv("/Users/sa9/Desktop/Data_Science_Project3/weather_api/data/json/br_final.csv").convert_dtypes()
br_final
# Out:
#     country     subdivision     type  million_60kgs_bag  year  \
# 0    Brazil    Minas Gerais  Arabica               16.2  2002
# 1    Brazil  Espirito Santo  Arabica                2.2  2002
# 2    Brazil  Espirito Santo  Robusta                7.5  2002
# 3    Brazil       Sao Paulo  Arabica                3.2  2002
# 4    Brazil          Parana  Arabica                0.5  2002
# ..      ...             ...      ...                ...   ...
# 110  Brazil    Minas Gerais  Arabica               28.5  2023
# 111  Brazil  Espirito Santo  Arabica                4.4  2023
# 112  Brazil  Espirito Santo  Robusta               16.6  2023
# 113  Brazil       Sao Paulo  Arabica                5.1  2023
# 114  Brazil          Parana  Arabica                0.8  2023
#
#      nonbear_mill_trees  bear_mill_trees  nonbear_thous_hect  bear_thous_hect  \
# 0                  1500             4465                 495             2120
# ...

# %%
# Load in the firstv 10 row
br_final.head(10)
# Out:
#   country     subdivision     type  million_60kgs_bag  year  \
# 0  Brazil    Minas Gerais  Arabica               16.2  2002
# 1  Brazil  Espirito Santo  Arabica                2.2  2002
# 2  Brazil  Espirito Santo  Robusta                7.5  2002
# 3  Brazil       Sao Paulo  Arabica                3.2  2002
# 4  Brazil          Parana  Arabica                0.5  2002
# 5  Brazil    Minas Gerais  Arabica               26.7  2003
# 6  Brazil  Espirito Santo  Arabica                3.0  2003
# 7  Brazil  Espirito Santo  Robusta                8.5  2003
# 8  Brazil       Sao Paulo  Arabica                5.9  2003
# 9  Brazil          Parana  Arabica                2.6  2003
#
#    nonbear_mill_trees  bear_mill_trees  nonbear_thous_hect  bear_thous_hect  \
# 0                1500             4465                 495             2120
# 1                1500             4465                 495             2120
# ...

# %%
br_final.dropna()
# Out:
#     country     subdivision     type  million_60kgs_bag  year  \
# 4    Brazil          Parana  Arabica                0.5  2002
# 9    Brazil          Parana  Arabica                2.6  2003
# 14   Brazil          Parana  Arabica                2.2  2004
# 19   Brazil          Parana  Arabica                2.6  2005
# 24   Brazil          Parana  Arabica                1.8  2006
# ..      ...             ...      ...                ...   ...
# 105  Brazil    Minas Gerais  Arabica               24.5  2022
# 106  Brazil  Espirito Santo  Arabica                3.7  2022
# 107  Brazil  Espirito Santo  Robusta               15.7  2022
# 108  Brazil       Sao Paulo  Arabica                4.6  2022
# 109  Brazil          Parana  Arabica                1.0  2022
#
#      nonbear_mill_trees  bear_mill_trees  nonbear_thous_hect  bear_thous_hect  \
# 4                  1500             4465                 495             2120
# ...

# %%
br_final.describe()
# Out:
#        million_60kgs_bag  nonbear_mill_trees  bear_mill_trees  \
# count              115.0               110.0            110.0
# mean            8.991304          995.045455      5648.409091
# std             9.213987          308.965495       371.296348
# min                  0.5               466.0           4465.0
# 25%                  2.6               679.0           5640.0
# 50%                  4.8              1052.5           5737.5
# 75%                 12.3              1185.0           5810.0
# max                 34.8              1510.0           6200.0
#
#        nonbear_thous_hect  bear_thous_hect  trees_hect_bear  \
# count               110.0            110.0            110.0
# mean           298.136364      2146.409091      2639.772727
# std             97.127692        96.260664       244.494223
# min                 148.0           2010.0           2106.0
# 25%                 205.0           2070.0           2552.0
# ...

# %%
# Convert the `year` column into a datetime data-type
br_final["year"] = pd. to_datetime(br_final["year"])
br_final. set_index("year", inplace=True)
br_final. head ( )
# Out:
#                               country     subdivision     type  \
# year
# 1970-01-01 00:00:00.000002002  Brazil    Minas Gerais  Arabica
# 1970-01-01 00:00:00.000002002  Brazil  Espirito Santo  Arabica
# 1970-01-01 00:00:00.000002002  Brazil  Espirito Santo  Robusta
# 1970-01-01 00:00:00.000002002  Brazil       Sao Paulo  Arabica
# 1970-01-01 00:00:00.000002002  Brazil          Parana  Arabica
#
#                                million_60kgs_bag  nonbear_mill_trees  \
# year
# 1970-01-01 00:00:00.000002002               16.2                1500
# 1970-01-01 00:00:00.000002002                2.2                1500
# 1970-01-01 00:00:00.000002002                7.5                1500
# 1970-01-01 00:00:00.000002002                3.2                1500
# 1970-01-01 00:00:00.000002002                0.5                1500
#
#                                bear_mill_trees  nonbear_thous_hect  \
# year
# 1970-01-01 00:00:00.000002002             4465                 495
# ...

# %%
.plot()br_final
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# I see a steady unemployment rate, probably due to covid throughtout the year.

# %%
br_final["avg_unemp_perc"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# I see a dropdown due to unemployment. This will have a negative effect on harvest.

# %%
br_final["million_60kgs_bag"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# I see an outlier, and a right skew explaining the negative effect of unemplyment on harvest.
